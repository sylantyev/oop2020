# %%
def result():
    return "операція проведена..."

#прогнозований результат
print(type(result))

# %%
def first(function):
    def wrapper():
        return "<перше_wrapper>" + function() + "</перше_wrapper>"
    return wrapper
 

def second(function):
    def wrapper():
        return "<друге_wrapper>" + function() + "</друге_wrapper>"
    return wrapper
 
@first
@second

def result():
    return "операція проведена..."
 
print (result())

# %%
# скільки разів можливо декорирування функції
def first(function):
    def wrapper():
        return "<перше_wrapper>" + function() + "</перше_wrapper>"
    return wrapper
 

def second(function):
    def wrapper():
        return "<друге_wrapper>" + function() + "</друге_wrapper>"
    return wrapper

@first
@second
#
#

def result():
    return "операція проведена..."
 

print (result())

# %%
# декоратори це звичайні функції 
def function_decorator():
    print ("декоратор є звичайною функцією")
    def wrapper(func):
        print ("функція що повертається декоратором")
        return func()
    return wrapper

def decorated_function():
    print ("Декоріруєма функція")
 
example_decorator = function_decorator()

# decorated_function = example_decorator(decorated_function)

print(type(example_decorator))

# %% [markdown]
# Створення декораторів функцій

# %%
def decorator_maker():
 
    print ("функція створення декоратора, викликається один раз : "+\
          "у випадку, коли є звернення для створення декоратора.")
 
    def my_decorator(func):
 
        print ("це - декоратор! Викливається лише раз, під час декорирування функції")
 
        def wrapped():
            print ("це - обгортка навколо декоріруємої функції"
                  "викликається кожного разу, коли викликається декоріруєма функція"
                  "повертається результат роботи декоріруємої функції")
            return func()
 
        print ("Поверненя обгорнутої функції")
 
        return wrapped
 
    print ("Саме тут повернення декоратора після звернення до нього")
    return my_decorator

new_decorator = decorator_maker()

# %%
def decorator_maker():
 
    print ("функція створення декоратора, викликається один раз : "+\
          "у випадку, коли є звернення для створення декоратора.")
 
    def my_decorator(func):
 
        print ("це - декоратор! Викливається лише раз, під час декорирування функції")
 
        def wrapped():
            print ("це - обгортка навколо декоріруємої функції"
                  "викликається кожного разу, коли викликається декоріруєма функція"
                  "повертається результат роботи декоріруємої функції")
            return func()
 
        print ("Поверненя обгорнутої функції")
 
        return wrapped
 
    print ("Саме тут повернення декоратора після звернення до нього")
    return my_decorator

new_decorator = decorator_maker()

def decorated_function():
    print ("Декоріруєма функція")
 
decorated_function = new_decorator(decorated_function)

# %%
def decorator_maker():
 
    print ("функція створення декоратора, викликається один раз : "+\
          "у випадку, коли є звернення для створення декоратора.")
 
    def my_decorator(func):
 
        print ("це - декоратор! Викливається лише раз, під час декорирування функції")
 
        def wrapped():
            print ("це - обгортка навколо декоріруємої функції"
                  "викликається кожного разу, коли викликається декоріруєма функція"
                  "повертається результат роботи декоріруємої функції")
            return func()
 
        print ("Поверненя обгорнутої функції")
 
        return wrapped
 
    print ("Саме тут повернення декоратора після звернення до нього")
    return my_decorator

new_decorator = decorator_maker()


def decorated_function():
    print ("Декоріруєма функція 2")
decorated_function = decorator_maker()(decorated_function)

decorated_function()

# %%
def decorator_maker():
 
    print ("функція створення декоратора, викликається один раз : "+\
          "у випадку, коли є звернення для створення декоратора.")
 
    def my_decorator(func):
 
        print ("це - декоратор! Викливається лише раз, під час декорирування функції")
 
        def wrapped():
            print ("це - обгортка навколо декоріруємої функції"
                  "викликається кожного разу, коли викликається декоріруєма функція"
                  "повертається результат роботи декоріруємої функції")
            return func()
 
        print ("Поверненя обгорнутої функції")
 
        return wrapped
 
    print ("Саме тут повернення декоратора після звернення до нього")
    return my_decorator

new_decorator = decorator_maker()

def decorated_function():
    print ("Декоріруєма функція")
 
decorated_function = new_decorator(decorated_function)

decorated_function()

def decorated_function2():
    print ("Декоріруєма функція 2")
decorated_function = decorator_maker()(decorated_function2)

decorated_function()

# %%
# декоратори це звичайні функції 
def my_decorator():
    print ("декоратор це звичайна функция")
    def wrapper(func):
        print ("функція, що повертається декоратором")
        return func()
    return wrapper
 
# виклик функції декоратора без використання символу "@".
 
def my_function():
    print ("моя функція")


example_decor = my_decorator()

decorated_function = example_decor(my_function)
# декоратор це звичайна функция

# прогнозований результат 
# print(type(decorated_function))
