# %% [markdown]
# ## SRP

# %%
class Customer:
    def __init__(self, name: str):
        self.name = name

    def get_name(self) -> str:
        return f'Я покупець цього товару, але не найкращий : {self.name}'

    def save(self, animal):
        return f'Збереження  {animal.name} до БД'


def main():
    customer = Customer('ПІБ найкращого покупця')
    save = customer.save(customer)
    print(save)   
#   print(type(Customer.get_name))
#   синхронізція методів одного класу    
#   name = customer.get_name()
#   print(name)
    

if __name__ == '__main__':
    main()

# %%
class Customer:
    def __init__(self, name: str):
        self.name = name

    def get_name(self) -> str:
        return f'Я покупець цього товару, але не найкращий : {self.name}'


class CustomerDB:
    def get_customer(self, id) -> Customer:
        pass

    def save(self, customer: Customer):
        return f'Збереження- {customer.name} -до БД'


def main():

    customer = Customer('ПІБ найкращого покупця')
    db = CustomerDB()
    save = db.save(customer)
    print(save)
    print(type(CustomerDB))

    name = customer.get_name()
    print(name)
    
if __name__ == '__main__':
    main()

# %%
class Customer:
    def __init__(self, name: str):
        self.name = name
        self.db = CustomerDB()

    def get_name(self) -> str:
        return f'Я покупець цього товару, але не найкращий : {self.name}'

    def get(self, id):
        return self.db.get_customer(id)

    def save(self):
        dbsave = self.db.save(customer=self)
        return dbsave


class CustomerDB:
    def get_customer(self, id) -> Customer:
        pass

    def save(self, customer: Customer):
        return f'Збереження- {customer.name} -до БД'


customer = Customer('ПІБ2 найкращого покупця')
customer.save()

def main():

    customer = Customer('ПІБ найкращого покупеця')
    save = customer.save()
    print(save)

#name = customer.get_name()
#print(name)
    
    
    
if __name__ == '__main__':
    main()

# %% [markdown]
# ## OCP

# %%
#1-n 
class Animal:
    def __init__(self, name: str):
        self.name = name

    def get_name(self) -> str:
        return f'Мене звуть : {self.name}'


def animal_sound(animals: list):
    for animal in animals:
        if animal.name == 'Лев':
            print('я можу так: рррррррр!!!')
        elif animal.name == 'Миша':
            print('я можу так: пікпікпік!!!')
#        else: 
#            print('нічого такого я не можу')


def main():

    animals = [
        Animal('Лев'),
        Animal('Миша')
#        Animal('Змія')
        
        
    ]

    animal_sound(animals)
    

if __name__ == '__main__':
    main()

# %%
#2-n
class Animal:
    def __init__(self, name: str):
        self.name = name

    def get_name(self) -> str:
        return f'Мене звуть : {self.name}'

def animal_sound(animals: list):
    for animal in animals:
        if animal.name == 'Лев':
            print('я можу так: рррррррр!!!')
        elif animal.name == 'Миша':
            print('я можу так: пікпікпік!!!')
        elif animal.name == 'Змія':
            print('я можу так: шшшшшшшш !!!')


def main():

    animals = [
        Animal('Лев'),
        Animal('Миша'),
        Animal('Змія')
    ]

    animal_sound(animals)
    


if __name__ == '__main__':
    main()

# %%
#3-n
class Discount:
    def __init__(self, customer, price):
        self.customer = customer
        self.price = price

    def get_discount(self):
        if self.customer == 'звичайний':
            return self.price * 0.2
        if self.customer == 'ВІП':
            return self.price * 0.4


def main():

    customer1, price1 = 'звичайний', 100
    assert Discount(customer1, price1).get_discount() == 20.0

    customer2, price2 = 'ВІП', 100
    assert Discount(customer2, price2).get_discount() == 40.0
    
    print(customer1, price1)
    print(customer2, price2)
    
    
if __name__ == '__main__':
    main()

# %%
#1.1-y
class Animal:
    def __init__(self, name: str):
        self.name = name

    def get_name(self) -> str:
        return f'Мене звуть : {self.name}'

    def make_sound(self):
        pass


class Lion(Animal):
    def make_sound(self):
        return 'я можу так: рррррррр!!!'


class Mouse(Animal):
    def make_sound(self):
        return 'я можу так: пікпікпік!!!'


def animal_sound(animals: list):
    for animal in animals:
        print(animal.make_sound())


def main():

    animals = [
        Lion('Лев'),
        Mouse('Миша')
                
    ]

    animal_sound(animals)


if __name__ == '__main__':
    main()

# %%
#1.1-y
class Animal:
    def __init__(self, name: str):
        self.name = name

    def get_name(self) -> str:
        return f'Мене звуть : {self.name}'

    def make_sound(self):
        pass


class Lion(Animal):
    def make_sound(self):
        return 'я можу так: рррррррр!!!'


class Mouse(Animal):
    def make_sound(self):
        return 'я можу так: пікпікпік!!!'

class Snake(Animal):
    def make_sound(self):
        return 'я можу так: шшшшшшшш !!!'
    
def animal_sound(animals: list):
    for animal in animals:
        print(animal.make_sound())


def main():

    animals = [
        Lion('Лев'),
        Mouse('Миша'),
        Snake('Змія')
                
    ]

    animal_sound(animals)


if __name__ == '__main__':
    main()

# %%
#2.1-y
class Animal:
    def __init__(self, name: str):
        self.name = name

    def get_name(self) -> str:
        return f'Мене звуть : {self.name}'

    def make_sound(self):
        pass


class Lion(Animal):
    def make_sound(self):
        return 'я можу так: рррррррр!!!'


class Mouse(Animal):
    def make_sound(self):
        return 'я можу так: пікпікпік!!!'


class Snake(Animal):
    def make_sound(self):
        return 'я можу так: шшшшшшшш !!!'


def animal_sound(animals: list):
    for animal in animals:
        print(animal.make_sound())


def main():

    animals = [
        Lion('Лев'),
        Mouse('Миша'),
        Snake('Питон')
    ]

    animal_sound(animals)


if __name__ == '__main__':
    main()

# %%
#3.1-y
class Discount:
    def __init__(self, customer, price):
        self.customer = customer
        self.price = price

    def get_discount(self):
        return self.price * 0.2


class VIPDiscount(Discount):
    def get_discount(self):
        return super().get_discount() * 2


class SuperVIPDiscount(VIPDiscount):
    def get_discount(self):
        return super().get_discount() * 2


def main():

    customer, price = 'Лютий', 100

    assert Discount(customer, price).get_discount() == 20.0
    assert VIPDiscount(customer, price).get_discount() == 40.0
    assert SuperVIPDiscount(customer, price).get_discount() == 80.0


if __name__ == '__main__':
    main()

# %% [markdown]
# ## Liskov

# %%
#1 
DEFAULT_LION_LEG_COUNT = 4
DEFAULT_MOUSE_LEG_COUNT = 4
DEFAULT_SNAKE_LEG_COUNT = 0

class Animal:
    pass

class Lion(Animal):
    pass

class Mouse(Animal):
    pass

class Snake(Animal):
    pass

def animal_leg_count(animals: list):
    for animal in animals:
        if isinstance(animal, Lion):
            print(DEFAULT_LION_LEG_COUNT)
        elif isinstance(animal, Mouse):
            print(DEFAULT_MOUSE_LEG_COUNT)
        elif isinstance(animal, Snake):
            print(DEFAULT_SNAKE_LEG_COUNT)

def main():

    animals = [
        Lion(),
        Mouse(),
        Snake()
    ]

    animal_leg_count(animals)

if __name__ == '__main__':
    main()

# %%
#1+crocodile 
DEFAULT_LION_LEG_COUNT = 4
DEFAULT_MOUSE_LEG_COUNT = 4
DEFAULT_SNAKE_LEG_COUNT = 0
DEFAULT_CROCODILE_LEG_COUNT = 4

class Animal:
    pass

class Lion(Animal):
    pass

class Mouse(Animal):
    pass

class Snake(Animal):
    pass

class Crocodile(Animal):
    pass

def animal_leg_count(animals: list):
    for animal in animals:
        if isinstance(animal, Lion):
            print(DEFAULT_LION_LEG_COUNT)
        elif isinstance(animal, Mouse):
            print(DEFAULT_MOUSE_LEG_COUNT)
        elif isinstance(animal, Snake):
            print(DEFAULT_SNAKE_LEG_COUNT)
        elif isinstance(animal, Crocodile):
            print(DEFAULT_CROCODILE_LEG_COUNT)

def main():

    animals = [
        Lion(),
        Mouse(),
        Snake(),
        Crocodile()
    ]

    animal_leg_count(animals)

if __name__ == '__main__':
    main()

# %%
#1.1-y
DEFAULT_LION_LEG_COUNT = 4
DEFAULT_MOUSE_LEG_COUNT = 4
DEFAULT_SNAKE_LEG_COUNT = 0

class Animal:
    def get_legs_count(self):
        pass

class Lion(Animal):
    def get_legs_count(self):
        return DEFAULT_LION_LEG_COUNT

class Mouse(Animal):
    def get_legs_count(self):
        return DEFAULT_MOUSE_LEG_COUNT

class Snake(Animal):
    def get_legs_count(self):
        return DEFAULT_SNAKE_LEG_COUNT


def animal_leg_count(animals: list):
    for animal in animals:
        print(animal.get_legs_count())

def main():

    animals = [
        Lion(),
        Mouse(),
        Snake()
    ]

    animal_leg_count(animals)


if __name__ == '__main__':
    main()

# %%
#1.1-y
DEFAULT_LION_LEG_COUNT = 4
DEFAULT_MOUSE_LEG_COUNT = 4
DEFAULT_SNAKE_LEG_COUNT = 0
DEFAULT_CROCODILE_LEG_COUNT = 4

class Animal:
    def get_legs_count(self):
        pass

class Lion(Animal):
    def get_legs_count(self):
        return DEFAULT_LION_LEG_COUNT

class Mouse(Animal):
    def get_legs_count(self):
        return DEFAULT_MOUSE_LEG_COUNT

class Snake(Animal):
    def get_legs_count(self):
        return DEFAULT_SNAKE_LEG_COUNT

class Crocodile(Animal):
    def get_legs_count(self):
        return DEFAULT_CROCODILE_LEG_COUNT

    
def animal_leg_count(animals: list):
    for animal in animals:
        print(animal.get_legs_count())

def main():

    animals = [
        Lion(),
        Mouse(),
        Snake(),
        Crocodile()
    ]

    animal_leg_count(animals)


if __name__ == '__main__':
    main()

# %% [markdown]
# ## ISP

# %%
#1-n
from abc import ABCMeta, abstractmethod
from six import with_metaclass

DEFAULT_LION_LEG_COUNT = 4
DEFAULT_MOUSE_LEG_COUNT = 4
DEFAULT_SNAKE_LEG_COUNT = 0


class Animal(with_metaclass(ABCMeta)):

    @abstractmethod
    def get_legs_lion(self):
        raise NotImplementedError

    @abstractmethod
    def get_legs_mouse(self):
        raise NotImplementedError

    @abstractmethod
    def get_legs_snake(self):
        raise NotImplementedError


class Lion(Animal):

    def get_legs_lion(self):
        print(DEFAULT_LION_LEG_COUNT)

    def get_legs_mouse(self):
        print(DEFAULT_MOUSE_LEG_COUNT)

    def get_legs_snake(self):
        print(DEFAULT_SNAKE_LEG_COUNT)


class Mouse(Animal):

    def get_legs_lion(self):
        print(DEFAULT_LION_LEG_COUNT)

    def get_legs_mouse(self):
        print(DEFAULT_MOUSE_LEG_COUNT)

    def get_legs_snake(self):
        print(DEFAULT_SNAKE_LEG_COUNT)


class Snake(Animal):

    def get_legs_lion(self):
        print(DEFAULT_LION_LEG_COUNT)

    def get_legs_mouse(self):
        print(DEFAULT_MOUSE_LEG_COUNT)

    def get_legs_snake(self):
        print(DEFAULT_SNAKE_LEG_COUNT)


class Manager():

    def __init__(self):
        self.animal = None

    def set_animal(self, animal):
        assert isinstance(
            animal, Animal), "`animal` must be of type {}".format(Animal)

        self.animal = animal

    def get_legs_lion(self):
        self.animal.get_legs_lion()

    def get_legs_mouse(self):
        self.animal.get_legs_mouse()

    def get_legs_snake(self):
        self.animal.get_legs_snake()


def main():

    manager = Manager()
    manager.set_animal(Lion())
    manager.get_legs_lion()

    manager.set_animal(Mouse())
    manager.get_legs_mouse()

    manager.set_animal(Snake())
    manager.get_legs_snake()


if __name__ == '__main__':
    main()

# %%
#1.1-y
from abc import ABCMeta, abstractmethod
from six import with_metaclass

DEFAULT_LION_LEG_COUNT = 4
DEFAULT_MOUSE_LEG_COUNT = 4
DEFAULT_SNAKE_LEG_COUNT = 0

class Animal(with_metaclass(ABCMeta)):

    @abstractmethod
    def get_legs_count(self):
        pass


class Manager():

    def __init__(self):
        self.animal = None

    def set_animal(self, animal):
        assert isinstance(
            animal, Animal), "`animal` must be of type {}".format(Animal)

        self.animal = animal

    def get_legs_count(self):
        self.animal.get_legs_count()


class Lion(Animal):

    def get_legs_count(self):
        print(DEFAULT_LION_LEG_COUNT)


class Mouse(Animal):

    def get_legs_count(self):
        print(DEFAULT_MOUSE_LEG_COUNT)


class Snake(Animal):

    def get_legs_count(self):
        print(DEFAULT_SNAKE_LEG_COUNT)


def main():

    manager = Manager()
    manager.set_animal(Lion())
    manager.get_legs_count()

    manager.set_animal(Mouse())
    manager.get_legs_count()

    manager.set_animal(Snake())
    manager.get_legs_count()


if __name__ == '__main__':
    main()

# %% [markdown]
# ## DIP

# %%
#1-n
DEFAULT_LION_LEG_COUNT = 4
DEFAULT_MOUSE_LEG_COUNT = 4


class Lion:

    def get_legs_count(self):
        print(DEFAULT_LION_LEG_COUNT)


class Mouse:

    def get_legs_count(self):
        print(DEFAULT_MOUSE_LEG_COUNT)


class Manager:

    def __init__(self):
        self.animal = None

    def set_animal(self, animal):
        assert isinstance(
            animal, Lion), "`animal` must be of type {}".format(Lion)

        self.animal = animal

    def get_legs_count(self):
        if self.animal is not None:
            self.animal.get_legs_count()


def main():

    lion = Lion()
    manager = Manager()
    manager.set_animal(lion)
    manager.get_legs_count()

    # не вовинно працювати...
    mouse = Mouse()
    try:
        manager.set_animal(mouse)
    except AssertionError:
        print("програма не підтримує мишу ...")


if __name__ == '__main__':
    main()

# %%
#2.1-y
from abc import ABCMeta, abstractmethod
from six import with_metaclass

DEFAULT_LION_LEG_COUNT = 4
DEFAULT_MOUSE_LEG_COUNT = 4
DEFAULT_SNAKE_LEG_COUNT = 0


class Animal(with_metaclass(ABCMeta)):

    @abstractmethod
    def get_legs_count(self):
        pass


class Lion(Animal):

    def get_legs_count(self):
        print(DEFAULT_LION_LEG_COUNT)


class Mouse(Animal):

    def get_legs_count(self):
        print(DEFAULT_MOUSE_LEG_COUNT)


class Snake(Animal):

    def get_legs_count(self):
        print(DEFAULT_SNAKE_LEG_COUNT)


class Manager:

    def __init__(self):
        self.animal = None

    def set_animal(self, animal):
        assert isinstance(
            animal, Animal), "`animal` must be of type {}".format(Animal)

        self.animal = animal

    def get_legs_count(self):
        if self.animal is not None:
            self.animal.get_legs_count()


def main():

    lion = Lion()
    manager = Manager()
    manager.set_animal(lion)
    manager.get_legs_count()

    # The following will work!
    mouse = Mouse()
    try:
        manager.set_animal(mouse)
        manager.get_legs_count()
    except AssertionError:
        print("програма не підтримує мишу ...")

    snake = Snake()
    manager.set_animal(snake)
    manager.get_legs_count()


if __name__ == '__main__':
    main()
