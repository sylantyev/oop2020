# %% [markdown]
# ## Індивідуальне завдання №1
#
# Використовуючи шаблон наведеної функції зробити коригування в коді для отриманння визначеного результату
#
# ```
# def make_adder(x):
#     def adder(y):
#         return x**y
#     return adder
#
# add_two = make_adder(?)
#
# add_two(?)
# ```
# результат функції **add_two(?)** повинен дорівнювати **1024**

# %%
# коригований код Індивідуального завдання №1 тут

# %% [markdown]
# ## Індивідуальне завдання №2
# Використовуючи шаблон коду створити функцію, яка перетворить першу літеру назв на велику
#
# ```
# from functools import reduce
#
# #Завдання: Перетворити перші літери кожного елементу списку назв до великих літер
# my_pets = ['київ', 'львів', 'одеса', 'полтава', 'харків', 'суми', 'житомир`]
# ```

# %%
# код Індивідуального завдання №2 тут

# %% [markdown]
# ## Індивідуальне завдання №3
# Використовуючи функцію фищих порядків Zip перетворити два списки в кортеж, причому всі елементи кортежу повинні бути відсотртовані від найменших значень до найбільших
# ```
# # створення відсортованого кортежу
# strings = ['a', 'b', 'c', 'd', 'e', 'f', 'g']
# numbers = [7,6,5,4,3,2,1]
# ```

# %%
# код Індивідуального завдання №3 тут

# %% [markdown]
# ## Індивідуальне завдання №4
# На основі створення власної функції і функції вищого порядку **filter** у відсортованому порядку роздрукувати список всіх елементів списку, які перевищують 51
#
# ```
# # фільтрація елементів списку
# age = [71, 52, 28, 51, 65, 19, 76, 100, 88, 51, 52]
#
# ```

# %%
# код Індивідуального завдання №4 тут

# %% [markdown]
# ## Індивідуальне завдання №5
# На основі створення власної функції і функції вищого порядку **reduce** поєднати всі елементи обох списків. Вивести результат.
#
# ```
# numbers = [7,6,5,4,3,2,1]
# age = [71, 52, 28, 51, 65, 19, 76, 100, 88, 51, 52]
# ```

# %%
# код Індивідуального завдання №5 тут

# %% [markdown]
# ## Індивідуальне завдання №6
# Із використанням анонімної функції **lambda** вивести список кореня другого ступеня для всіх елементів списку
# ```
# [1, 4, 9, 16, 25, 36, 49, 64, 81]
# ```

# %%
# код Індивідуального завдання №6 тут

# %% [markdown]
# ## Індивідуальне завдання №7
# Із використанням анонімної функції **lambda** вивести, у відсортованому зростаючому порядку згідно першого елементу кожного кортежу, новий список відсортованих кортежів.
# ```
# [(18, 5), (4, 3), (21, 18), (12, -8), (6, 9)]
# ```

# %%
# код Індивідуального завдання №7 тут

# %% [markdown]
# ## Індивідуальне завдання №8
# Створити функцію визначення дублювання елементів списку. Вивести список елементів початкового списку, які в ньому дублюються.
# ```
# ['F', 'C', 'D', 'B', 'J', 'C', 'F', 'I', 'G', 'I', 'B', 'F']
# ```

# %%
# код Індивідуального завдання №8 тут

# %% [markdown]
# ## Індивідуальне завдання №9
#
# Створити функцію, яка повертає список булевих значень: **True**, якщо у вхідному списку число є простим і **False**, якщо інакше.
#
# Вхідний список значень задається з консолі.

# %%
# код Індивідуального завдання №9 тут

# %% [markdown]
# ## Індивідуальне завдання №10
#
# Створити функцію підрахунку слів у тексті. Вивести кількість слів.
# Текст, що подається на вхід функції, обирається з будь-якого сайту Інтернету: а)державною, б)англійською мовами.
#
# Текст не повинен перевищувати 3-рядків.

# %%
# код Індивідуального завдання №10 тут
